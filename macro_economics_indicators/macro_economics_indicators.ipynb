# %% [markdown]
# # Macro Economics Indicators
#
# **Autor:** Frederick Salazar Sanchez <br>
# **Date:** March of 2025 <br>
# **Description:** This notebook

# %%
import pandas as pd

# %%
df_pib = pd.read_csv('./data/in/countries_gdp_hist.csv',sep=';')

# %%
df_pib_per_capita = pd.read_csv('./data/in/pib_per_capita_countries_dataset.csv', sep=',')\
                      .drop(columns=['country_name',
                                     'region',
                                     'sub_region',
                                     'intermediate_region',
                                     'indicator_code',
                                     'indicator_name'])\
                      .rename(columns={'country_code':'country_code_percapita',
                                       'year':'year_percapita',
                                       'gdp_variation':'gdp_variation_percapita'})

# %%
df_exports = pd.read_csv('./data/in/export_goods_services_countries_dataset.csv', sep=',')\
                .drop(columns=['country_name',
                               'region',
                               'sub_region',
                               'intermediate_region',
                               'indicator_code',
                               'indicator_name'])\
                .rename(columns={'country_code':'country_code_exports',
                                 'year':'year_exports'})

# %%
df_inflation = pd.read_csv('./data/in/global_inflation_countries.csv', sep=',')\
                .drop(columns=['country_name',
                               'region',
                               'sub_region',
                               'intermediate_region',
                               'indicator_code',
                               'indicator_name'])\
                .rename(columns={'country_code':'country_code_inflation',
                                 'year':'year_inflation'})

# %%
df_imports = pd.read_csv('./data/in/import_goods_services_countries_dataset.csv', sep=',')\
                .drop(columns=['country_name',
                               'region',
                               'sub_region',
                               'intermediate_region',
                               'indicator_code',
                               'indicator_name'])\
                .rename(columns={'country_code':'country_code_imports',
                                 'year':'year_imports'})

# %% [markdown]
# # Creation a unique dataframe with all data

# %%
df_economics = pd.merge(df_pib, df_pib_per_capita,
                        left_on=['country_code', 'year'],
                        right_on=['country_code_percapita', 'year_percapita'],
                        how='left')\
                .merge(df_exports,
                       left_on=['country_code', 'year'],
                       right_on=['country_code_exports', 'year_exports'],
                       how='left')\
                .merge(df_imports,
                       left_on=['country_code', 'year'],
                       right_on=['country_code_imports', 'year_imports'],
                       how='left')\
                .merge(df_inflation,
                       left_on=['country_code', 'year'],
                       right_on=['country_code_inflation', 'year_inflation'],
                       how='left')\
                .drop(columns=['country_code_percapita',
                               'year_percapita',
                               'country_code_exports',
                               'year_exports',
                               'country_code_inflation',
                               'year_inflation',
                               'country_code_imports',
                               'year_imports'])

# %%
df_economics
# Out:
#       country_code region_name                  sub_region_name  \
# 0              ABW    AMERICAS  LATIN AMERICA AND THE CARIBBEAN
# 1              ABW    AMERICAS  LATIN AMERICA AND THE CARIBBEAN
# 2              ABW    AMERICAS  LATIN AMERICA AND THE CARIBBEAN
# 3              ABW    AMERICAS  LATIN AMERICA AND THE CARIBBEAN
# 4              ABW    AMERICAS  LATIN AMERICA AND THE CARIBBEAN
# ...            ...         ...                              ...
# 13755          ZWE      AFRICA               SUB-SAHARAN AFRICA
# 13756          ZWE      AFRICA               SUB-SAHARAN AFRICA
# 13757          ZWE      AFRICA               SUB-SAHARAN AFRICA
# 13758          ZWE      AFRICA               SUB-SAHARAN AFRICA
# 13759          ZWE      AFRICA               SUB-SAHARAN AFRICA
#
#       intermediate_region country_name                    income_group  year  \
# 0               CARIBBEAN        ARUBA                    INGRESO ALTO  1960
# 1               CARIBBEAN        ARUBA                    INGRESO ALTO  1961
# 2               CARIBBEAN        ARUBA                    INGRESO ALTO  1962
# 3               CARIBBEAN        ARUBA                    INGRESO ALTO  1963
# 4               CARIBBEAN        ARUBA                    INGRESO ALTO  1964
# ...                   ...          ...                             ...   ...
# 13755      EASTERN AFRICA     ZIMBABWE  PAÍSES DE INGRESO MEDIANO BAJO  2019
# 13756      EASTERN AFRICA     ZIMBABWE  PAÍSES DE INGRESO MEDIANO BAJO  2020
# 13757      EASTERN AFRICA     ZIMBABWE  PAÍSES DE INGRESO MEDIANO BAJO  2021
# 13758      EASTERN AFRICA     ZIMBABWE  PAÍSES DE INGRESO MEDIANO BAJO  2022
# 13759      EASTERN AFRICA     ZIMBABWE  PAÍSES DE INGRESO MEDIANO BAJO  2023
#
#           total_gdp  total_gdp_million  gdp_variation  gdp_per_capita  \
# 0      0.000000e+00           0.000000       0.000000        0.000000
# 1      0.000000e+00           0.000000       0.000000        0.000000
# 2      0.000000e+00           0.000000       0.000000        0.000000
# 3      0.000000e+00           0.000000       0.000000        0.000000
# 4      0.000000e+00           0.000000       0.000000        0.000000
# ...             ...                ...            ...             ...
# 13755  2.571741e+10       25717.409842      -6.332446     1684.027904
# 13756  2.686794e+10       26867.936445      -7.816951     1730.413489
# 13757  2.724052e+10       27240.515109       8.468017     1724.387731
# 13758  3.278975e+10       32789.751736       6.139263     2040.552459
# 13759  3.523137e+10       35231.367886       5.336730     2156.034004
#
#        gdp_variation_percapita  exports_of_goods_and_services  \
# 0                     0.000000                       0.000000
# 1                     0.000000                       0.000000
# 2                     0.000000                       0.000000
# 3                     0.000000                       0.000000
# 4                     0.000000                       0.000000
# ...                        ...                            ...
# 13755                -7.785580                      27.554156
# 13756                -9.333971                      22.293063
# 13757                 6.611911                      22.775241
# 13758                 4.343667                      27.872171
# 13759                      NaN                      21.579400
#
#        imports_of_goods_and_services  inflation_rate
# 0                           0.000000        0.000000
# 1                           0.000000        0.000000
# 2                           0.000000        0.000000
# 3                           0.000000        0.000000
# 4                           0.000000        0.000000
# ...                              ...             ...
# 13755                      28.241805      255.304991
# 13756                      25.020302      557.201817
# 13757                      28.071888       98.546105
# 13758                      36.891437      104.705171
# 13759                      29.215564        0.000000
#
# [13760 rows x 15 columns]

# %% [markdown]
# # save Proccessed File to csv

# %%
df_economics.to_csv('./data/out/macro_economics_indicators.csv', index=False)
