# %% [markdown]
# # Macro Economics Indicators
#
# **Autor:** Frederick Salazar Sanchez <br>
# **Date:** March of 2025 <br>
# **Description:** This notebook

# %%
import pandas as pd

# %%
df_pib = pd.read_csv('./data/in/countries_gdp_hist.csv',sep=';')

# %%
df_pib_per_capita = pd.read_csv('./data/in/pib_per_capita_countries_dataset.csv', sep=',')\
                      .drop(columns=['country_name',
                                     'region',
                                     'sub_region',
                                     'intermediate_region',
                                     'indicator_code',
                                     'indicator_name'])\
                      .rename(columns={'country_code':'country_code_percapita',
                                       'year':'year_percapita',
                                       'gdp_variation':'gdp_variation_percapita'})

# %%
df_exports = pd.read_csv('./data/in/export_goods_services_countries_dataset.csv', sep=',')\
                .drop(columns=['country_name',
                               'region',
                               'sub_region',
                               'intermediate_region',
                               'indicator_code',
                               'indicator_name'])\
                .rename(columns={'country_code':'country_code_exports',
                                 'year':'year_exports'})

# %%
df_inflation = pd.read_csv('./data/in/global_inflation_countries.csv', sep=',')\
                .drop(columns=['country_name',
                               'region',
                               'sub_region',
                               'intermediate_region',
                               'indicator_code',
                               'indicator_name'])\
                .rename(columns={'country_code':'country_code_inflation',
                                 'year':'year_inflation'})

# %%
df_imports = pd.read_csv('./data/in/import_goods_services_countries_dataset.csv', sep=',')\
                .drop(columns=['country_name',
                               'region',
                               'sub_region',
                               'intermediate_region',
                               'indicator_code',
                               'indicator_name'])\
                .rename(columns={'country_code':'country_code_imports',
                                 'year':'year_imports'})

# %% [markdown]
# # Creation a unique dataframe with all data

# %%
df_economics = pd.merge(df_pib, df_pib_per_capita,
                        left_on=['country_code', 'year'],
                        right_on=['country_code_percapita', 'year_percapita'],
                        how='left')\
                .merge(df_exports,
                       left_on=['country_code', 'year'],
                       right_on=['country_code_exports', 'year_exports'],
                       how='left')\
                .merge(df_imports,
                       left_on=['country_code', 'year'],
                       right_on=['country_code_imports', 'year_imports'],
                       how='left')\
                .merge(df_inflation,
                       left_on=['country_code', 'year'],
                       right_on=['country_code_inflation', 'year_inflation'],
                       how='left')\
                .drop(columns=['country_code_percapita',
                               'year_percapita',
                               'country_code_exports',
                               'year_exports',
                               'country_code_inflation',
                               'year_inflation',
                               'country_code_imports',
                               'year_imports'])

# %%
# Convertir las columnas numéricas de texto a float
cols_numericas = ["total_gdp", "total_gdp_million", "gdp_variation", 
                  "gdp_per_capita", "gdp_variation_percapita", 
                  "exports_of_goods_and_services", "imports_of_goods_and_services", "inflation_rate"]

df_economics[cols_numericas] = df_economics[cols_numericas].apply(pd.to_numeric, errors='coerce')

# %%
df_economics["country_name"] = df_economics["country_name"].mask(df_economics["country_code"] == "COD", "REPUBLIC DEMOCRATIC OF CONGO")

df_economics["country_name"] = df_economics["country_name"].mask(df_economics["country_code"] == "KOR", "REPUBLIC DEMOCRATIC OF KOREA")

df_economics["country_name"] = df_economics["country_name"].mask(df_economics["country_code"] == "MDA", "REPUBLIC OF MOLDOVA")

df_economics["country_name"] = df_economics["country_name"].mask(df_economics["country_code"] == "PSE", "STATE OF PALESTINE")

df_economics["country_name"] = df_economics["country_name"].mask(df_economics["country_code"] == "TZA", "UNITED REPUBLIC OF TANZANIA")

# %%
df_economics.dtypes
# Out:
# country_code                      object
# region_name                       object
# sub_region_name                   object
# intermediate_region               object
# country_name                      object
# income_group                      object
# year                               int64
# total_gdp                        float64
# total_gdp_million                float64
# gdp_variation                    float64
# gdp_per_capita                   float64
# gdp_variation_percapita          float64
# exports_of_goods_and_services    float64
# imports_of_goods_and_services    float64
# inflation_rate                   float64
# dtype: object

# %%
df_economics[df_economics['country_code'] == 'COD']
# Out:
#      country_code region_name     sub_region_name intermediate_region  \
# 2432          COD      AFRICA  SUB-SAHARAN AFRICA       MIDDLE AFRICA
# 2433          COD      AFRICA  SUB-SAHARAN AFRICA       MIDDLE AFRICA
# 2434          COD      AFRICA  SUB-SAHARAN AFRICA       MIDDLE AFRICA
# 2435          COD      AFRICA  SUB-SAHARAN AFRICA       MIDDLE AFRICA
# 2436          COD      AFRICA  SUB-SAHARAN AFRICA       MIDDLE AFRICA
# ...           ...         ...                 ...                 ...
# 2491          COD      AFRICA  SUB-SAHARAN AFRICA       MIDDLE AFRICA
# 2492          COD      AFRICA  SUB-SAHARAN AFRICA       MIDDLE AFRICA
# 2493          COD      AFRICA  SUB-SAHARAN AFRICA       MIDDLE AFRICA
# 2494          COD      AFRICA  SUB-SAHARAN AFRICA       MIDDLE AFRICA
# 2495          COD      AFRICA  SUB-SAHARAN AFRICA       MIDDLE AFRICA
#
#                       country_name            income_group  year  \
# 2432  REPUBLIC DEMOCRATIC OF CONGO  PAÍSES DE INGRESO BAJO  1960
# 2433  REPUBLIC DEMOCRATIC OF CONGO  PAÍSES DE INGRESO BAJO  1961
# 2434  REPUBLIC DEMOCRATIC OF CONGO  PAÍSES DE INGRESO BAJO  1962
# 2435  REPUBLIC DEMOCRATIC OF CONGO  PAÍSES DE INGRESO BAJO  1963
# 2436  REPUBLIC DEMOCRATIC OF CONGO  PAÍSES DE INGRESO BAJO  1964
# ...                            ...                     ...   ...
# 2491  REPUBLIC DEMOCRATIC OF CONGO  PAÍSES DE INGRESO BAJO  2019
# 2492  REPUBLIC DEMOCRATIC OF CONGO  PAÍSES DE INGRESO BAJO  2020
# 2493  REPUBLIC DEMOCRATIC OF CONGO  PAÍSES DE INGRESO BAJO  2021
# 2494  REPUBLIC DEMOCRATIC OF CONGO  PAÍSES DE INGRESO BAJO  2022
# 2495  REPUBLIC DEMOCRATIC OF CONGO  PAÍSES DE INGRESO BAJO  2023
#
#          total_gdp  total_gdp_million  gdp_variation  gdp_per_capita  \
# 2432  3.359404e+09        3359.404118       0.000000      220.074550
# 2433  3.086747e+09        3086.746857     -10.851376      197.080395
# 2434  3.779841e+09        3779.841429      21.200698      235.127291
# 2435  6.213186e+09        6213.185743       5.213990      376.383370
# 2436  2.881545e+09        2881.545273      -2.440224      169.949260
# ...            ...                ...            ...             ...
# 2491  5.177583e+10       51775.829877       4.384529      557.044161
# 2492  4.871696e+10       48716.961860       1.735423      507.521230
# 2493  5.532848e+10       55328.482784       6.200154      558.034077
# 2494  6.580155e+10       65801.547620       8.924448      642.612266
# 2495  6.638329e+10       66383.287003       8.560863      627.502182
#
#       gdp_variation_percapita  exports_of_goods_and_services  \
# 2432                 0.000000                       0.000000
# 2433               -13.114065                       0.000000
# 2434                18.084302                       0.000000
# 2435                 2.461361                       0.000000
# 2436                -5.016419                       0.000000
# ...                       ...                            ...
# 2491                 1.127914                      25.867665
# 2492                -1.489244                      28.604952
# 2493                 2.816565                      40.385830
# 2494                 5.469360                      45.497950
# 2495                      NaN                      44.245990
#
#       imports_of_goods_and_services  inflation_rate
# 2432                       0.000000        0.000000
# 2433                       0.000000        0.000000
# 2434                       0.000000        0.000000
# 2435                       0.000000        0.000000
# 2436                       0.000000       35.421065
# ...                             ...             ...
# 2491                      29.367493        0.000000
# 2492                      29.886806        0.000000
# 2493                      40.095482        0.000000
# 2494                      48.230717        0.000000
# 2495                      47.015275        0.000000
#
# [64 rows x 15 columns]

# %% [markdown]
# # save Proccessed File to csv

# %%
df_economics.to_csv('./data/out/macro_economics_indicators.csv', index=False, float_format="%.2f", sep=';', decimal=',')
